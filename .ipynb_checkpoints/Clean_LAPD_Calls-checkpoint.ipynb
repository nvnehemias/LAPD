# %%
import pandas as pd

# %%
file = "LAPD_Calls_for_Service_2014.csv"
df = pd.read_csv(file)

# %%
test_df = df

# %%
test_df.head()
# Out:
#    Incident Number  Reporting District Area Occurred Dispatch Date  \
# 0     140212004623                 127       Central    02/12/2014
# 1     140212004304                1385        Newton    02/12/2014
# 2     140212004626                1307        Newton    02/12/2014
# 3     140212004685                2015       Olympic    02/12/2014
# 4     140212004668                1636      Foothill    02/12/2014
#
#   Dispatch Time Call Type Code Call Type Description
# 0      18:11:47           415W                 WOMAN
# 1      18:11:44           415G                   GRP
# 2      18:11:41           594O             OFCR HLDG
# 3      18:11:29           1101     NARCOTIC ACTIVITY
# 4      18:10:58           904A                   AMB

# %%
test_df["Call Type Description"].drop_duplicates().tolist()
# Out:
# ['WOMAN',
#  'GRP',
#  'OFCR HLDG',
#  'NARCOTIC ACTIVITY',
#  'AMB',
#  'DOM VIOL',
#  'SUSP NOW',
#  'MAN ASSLTG WMN',
#  'HEARD ONLY',
#  'VIOLENT MALE',
#  'INVEST',
#  'SUSP J/L',
#  'SHOTS FIRED J/O',
#  'MAN',
#  'CODE 6',
#  'POSS',
#  'MAN IN VEH',
#  'REFUSING ID',
#  'POSS BFV SUSP',
#  'GTA SUSP',
#  'AMB INVEST',
#  'FIGHT',
#  'NARCOTIC SUSP',
#  'ABUSE',
#  'MAN/WMN',
#  'TRAFFIC STOP',
#  'CODE 30 RINGER',
#  'UNKNOWN TROUBLE',
#  'W/VEH J/O',
#  'POSS ABUSE SUSP',
#  'P/S SUSP',
#  'TRESPASS SUSP',
#  'NEIGHBOR',
#  'GTA SUSP NOW',
#  'JUV',
#  'H & R MISD',
#  'FAMILY',
#  'ADULT',
#  'MAN W/GUN',
#  'OTHER/459 SILENT',
#  'MOLEST SUSP',
#  'DOM VIOL R/O',
#  'SUSP',
#  'OTHER',
#  'POSS ABUSE INVEST',
#  'VIOLENT FEM',
#  'BUSN',
#  'AMB MALE',
#  'COMPLAINT',
#  'FEM',
#  'MOLEST INVEST',
#  'CHILD',
#  'POSS FEM',
#  'ROBBERY (211 SILENT)',
#  'CRUELTY',
#  'ABUSE INVEST',
#  'POSS MALE',
#  'COMP OF INJURY',
#  'JUV GRP',
#  'WMN ASSLTG MAN',
# ...

# %%
test_df["Call Type Description"] = test_df["Call Type Description"].apply(lambda x: change_word(x,"WOMAN","Woman"))

# %%
test_df
# Out:
#         Incident Number  Reporting District Area Occurred Dispatch Date  \
# 0          140212004623                 127       Central    02/12/2014
# 1          140212004304                1385        Newton    02/12/2014
# 2          140212004626                1307        Newton    02/12/2014
# 3          140212004685                2015       Olympic    02/12/2014
# 4          140212004668                1636      Foothill    02/12/2014
# ...                 ...                 ...           ...           ...
# 932776     141231006434                 396     Southwest    12/31/2014
# 932777     141231006436                 679     Hollywood    12/31/2014
# 932778     141231006443                1974       Mission    12/31/2014
# 932779     141231006447                1235   77th Street    12/31/2014
# 932780     141231006449                 375     Southwest    12/31/2014
#
#        Dispatch Time Call Type Code Call Type Description
# ...

# %%
test_df["Call Type Description"] = test_df["Call Type Description"].apply(lambda x: change_word(x,"AMB","Ambulance"))
test_df
# Out:
#         Incident Number  Reporting District Area Occurred Dispatch Date  \
# 0          140212004623                 127       Central    02/12/2014
# 1          140212004304                1385        Newton    02/12/2014
# 2          140212004626                1307        Newton    02/12/2014
# 3          140212004685                2015       Olympic    02/12/2014
# 4          140212004668                1636      Foothill    02/12/2014
# ...                 ...                 ...           ...           ...
# 932776     141231006434                 396     Southwest    12/31/2014
# 932777     141231006436                 679     Hollywood    12/31/2014
# 932778     141231006443                1974       Mission    12/31/2014
# 932779     141231006447                1235   77th Street    12/31/2014
# 932780     141231006449                 375     Southwest    12/31/2014
#
#        Dispatch Time Call Type Code Call Type Description
# ...

# %%
test_df["Call Type Description"].drop_duplicates().tolist()
# Out:
# ['Woman',
#  'GRP',
#  'OFCR HLDG',
#  'NARCOTIC ACTIVITY',
#  'Ambulance',
#  'DOM VIOL',
#  'SUSP NOW',
#  'MAN ASSLTG Woman',
#  'HEARD ONLY',
#  'VIOLENT MALE',
#  'INVEST',
#  'SUSP J/L',
#  'SHOTS FIRED J/O',
#  'MAN',
#  'CODE 6',
#  'POSS',
#  'MAN IN VEH',
#  'REFUSING ID',
#  'POSS BFV SUSP',
#  'GTA SUSP',
#  'Ambulance INVEST',
#  'Fight',
#  'NARCOTIC SUSP',
#  'ABUSE',
#  'MAN/WMN',
#  'TRAFFIC STOP',
#  'CODE 30 RINGER',
#  'UNKNOWN TROUBLE',
#  'W/VEH J/O',
#  'POSS ABUSE SUSP',
#  'P/S SUSP',
#  'TRESPASS SUSP',
#  'NEIGHBOR',
#  'GTA SUSP NOW',
#  'JUV',
#  'H & R MISD',
#  'FAMILY',
#  'ADULT',
#  'MAN W/GUN',
#  'OTHER/459 SILENT',
#  'MOLEST SUSP',
#  'DOM VIOL R/O',
#  'SUSP',
#  'OTHER',
#  'POSS ABUSE INVEST',
#  'VIOLENT FEM',
#  'BUSN',
#  'Ambulance MALE',
#  'COMPLAINT',
#  'FEM',
#  'MOLEST INVEST',
#  'CHILD',
#  'POSS FEM',
#  'ROBBERY (211 SILENT)',
#  'CRUELTY',
#  'ABUSE INVEST',
#  'POSS MALE',
#  'COMP OF INJURY',
#  'JUV GRP',
# ...

# %%
def change_word(input_string: str, find_word: str, output_word: str):
    input_string = input_string.split(" ")
    list_word = []
    
    
    if len(input_string) > 1:
        input_string = " ".join(input_string)
        if input_string == find_word:
            input_string = output_word
        list_word.append(input_string)
    else:
        for i in input_string:
            if find_word == i:
                i = output_word
        else:
            i = i
        list_word.append(i)
    
    return " ".join(str(j) for j in list_word)

# %%
test_2 = df

# %%
test_2["Call Type Description"] = test_2["Call Type Description"].apply(lambda x: change_word(x,"PARTY","Party"))
test_2
# Out:
#         Incident Number  Reporting District Area Occurred Dispatch Date  \
# 0          140212004623                 127       Central    02/12/2014
# 1          140212004304                1385        Newton    02/12/2014
# 2          140212004626                1307        Newton    02/12/2014
# 3          140212004685                2015       Olympic    02/12/2014
# 4          140212004668                1636      Foothill    02/12/2014
# ...                 ...                 ...           ...           ...
# 932776     141231006434                 396     Southwest    12/31/2014
# 932777     141231006436                 679     Hollywood    12/31/2014
# 932778     141231006443                1974       Mission    12/31/2014
# 932779     141231006447                1235   77th Street    12/31/2014
# 932780     141231006449                 375     Southwest    12/31/2014
#
#        Dispatch Time Call Type Code Call Type Description
# ...
